# %%
import pandas as pd
from sklearn import linear_model

# %%
df0 = pd.read_csv('EPLCSV.csv', sep='\t')
df0.to_csv('EPLdata.csv', sep=',', index=False)
df = pd.read_csv('EPLdata.csv')
df
# Out:
#                HomeTeam                AwayTeam  FTH Goals  FTA Goals  \
# 0          Ipswich Town  Brighton & Hove Albion          0          2
# 1            Man United             Southampton          3          1
# 2               Everton             Aston Villa          0          1
# 3             Leicester          Crystal Palace          0          2
# 4             Newcastle                  Wolves          3          0
# ...                 ...                     ...        ...        ...
# 12148       Southampton                 Everton          0          2
# 12149  Sheffield United                 Swindon          3          1
# 12150         Liverpool          Sheffield Weds          2          0
# 12151       Aston Villa                     QPR          4          1
# 12152            Oldham                 Ipswich          0          3
#
#       FT Result
# 0             A
# 1             H
# 2             A
# 3             A
# 4             H
# ...         ...
# ...

# %%
df.HomeTeam = df.HomeTeam.fillna('NA')
df.AwayTeam	 = df.AwayTeam	.fillna('NA')
df['FTH Goals'] = df['FTH Goals'].fillna(0)
df['FTA Goals'] = df['FTA Goals'].fillna(0)
df['FT Result'] = df['FT Result'].fillna('D')
df['Home_Team_Encoded'] = pd.factorize(df['HomeTeam'])[0]
df['Away_Team_Encoded'] = pd.factorize(df['AwayTeam'])[0]
df['FT_Result_Encoded'] = pd.factorize(df['FT Result'])[0]
df
# Out:
#                HomeTeam                AwayTeam  FTH Goals  FTA Goals  \
# 0          Ipswich Town  Brighton & Hove Albion          0          2
# 1            Man United             Southampton          3          1
# 2               Everton             Aston Villa          0          1
# 3             Leicester          Crystal Palace          0          2
# 4             Newcastle                  Wolves          3          0
# ...                 ...                     ...        ...        ...
# 12148       Southampton                 Everton          0          2
# 12149  Sheffield United                 Swindon          3          1
# 12150         Liverpool          Sheffield Weds          2          0
# 12151       Aston Villa                     QPR          4          1
# 12152            Oldham                 Ipswich          0          3
#
#       FT Result  Home_Team_Encoded  Away_Team_Encoded  FT_Result_Encoded
# ...

# %%
reg = linear_model.LinearRegression()
X = df[['Home_Team_Encoded','Away_Team_Encoded']]
Y = df[['FTH Goals','FTA Goals']]
reg.fit(X,Y)
# Out:
# LinearRegression()

# %%
Home_Teams = df[['HomeTeam', 'Home_Team_Encoded']].drop_duplicates().reset_index(drop=True)
print("Home teams")
Home_Teams
# Out:
# Home teams
#                   HomeTeam  Home_Team_Encoded
# 0             Ipswich Town                  0
# 1               Man United                  1
# 2                  Everton                  2
# 3                Leicester                  3
# 4                Newcastle                  4
# 5                  Arsenal                  5
# 6                Brentford                  6
# 7                  Chelsea                  7
# 8                 West Ham                  8
# 9            Nott'm Forest                  9
# 10                  Wolves                 10
# 11                  Fulham                 11
# 12               Liverpool                 12
# 13               Tottenham                 13
# 14             Aston Villa                 14
# 15             Bournemouth                 15
# 16          Crystal Palace                 16
# 17                Man City                 17
# 18             Southampton                 18
# ...

# %%
Away_Teams = df[['AwayTeam', 'Away_Team_Encoded']].drop_duplicates().reset_index(drop=True)
print("Away teams")
Away_Teams
# Out:
# Away teams
#                   AwayTeam  Away_Team_Encoded
# 0   Brighton & Hove Albion                  0
# 1              Southampton                  1
# 2              Aston Villa                  2
# 3           Crystal Palace                  3
# 4                   Wolves                  4
# 5                Tottenham                  5
# 6                 Man City                  6
# 7              Bournemouth                  7
# 8                   Fulham                  8
# 9                Liverpool                  9
# 10           Nott'm Forest                 10
# 11                 Ipswich                 11
# 12              Man United                 12
# 13               Newcastle                 13
# 14               Leicester                 14
# 15                 Everton                 15
# 16                 Chelsea                 16
# 17                West Ham                 17
# 18               Brentford                 18
# ...

# %%
X_hat = pd.DataFrame([[15,10]], columns=['Home_Team_Encoded','Away_Team_Encoded'])
Y_hat = reg.predict(X_hat)
print(Y_hat)
# Out:
# [[1.50465647 1.22042511]]
